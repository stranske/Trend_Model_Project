# %% [markdown]
# # Volatility Scaling & Portfolio Analysis
#
# This notebook demonstrates how to:
# 1. Imports, Data Loader and Rf Detector
# 2. Select fund (month period logic)
# 3. Weight prep
# 4. Core Stats + Run Analysis
# 5. Export
# 6. Widget /UI
# 7. Output in-sample and out-of-sample results to Excel with formatting.

# %%
# Legacy helper and metric functions replaced by modules
# See trend_analysis.metrics and run_analysis.py

# %%
import pandas as pd
import numpy as np
import logging
import inspect
from collections import namedtuple
from typing import Dict, Optional, Callable
import ipywidgets as widgets
from ipyfilechooser import FileChooser
from IPython.display import display, clear_output
from trend_analysis.data import load_csv, identify_risk_free_fund
from trend_analysis.core.rank_selection import (
    FundSelectionConfig,
    RiskStatsConfig,
    select_funds,
    register_metric,
    METRIC_REGISTRY,
)
from trend_analysis.export import make_summary_formatter, export_to_excel
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 10
#       8 from ipyfilechooser import FileChooser
#       9 from IPython.display import display, clear_output
# ---> 10 from trend_analysis.data import load_csv, identify_risk_free_fund
#      11 from trend_analysis.core.rank_selection import (
#      12     FundSelectionConfig,
#      13     RiskStatsConfig,
#    (...)
#      16     METRIC_REGISTRY,
#      17 )
#      18 from trend_analysis.export import make_summary_formatter, export_to_excel
#
# File ~/Library/CloudStorage/Dropbox/Learning/Code/Trend Modeling Project/trend_analysis/__init__.py:3
#       1 """Trend analysis package."""
# ----> 3 from . import metrics, config, data, pipeline, export
#       4 from .data import load_csv, identify_risk_free_fund
#       5 from .export import (
#       6     register_formatter_excel,
#       7     reset_formatters_excel,
#    (...)
#      12     export_data,
#      13 )
#
# File ~/Library/CloudStorage/Dropbox/Learning/Code/Trend Modeling Project/trend_analysis/pipeline.py:12
#       9 from typing import Any
#      11 from .data import load_csv
# ---> 12 from .metrics import (
#      13     annualize_return,
#      14     annualize_volatility,
#      15     sharpe_ratio,
#      16     sortino_ratio,
#      17     max_drawdown,
#      18 )
#      20 if TYPE_CHECKING:  # pragma: no cover - for static type checking only
#      21     from .config import Config
#
# ImportError: cannot import name 'annualize_volatility' from 'trend_analysis.metrics' (/Users/teacher/Library/CloudStorage/Dropbox/Learning/Code/Trend Modeling Project/trend_analysis/metrics.py)

# %% [markdown]
# ## 2. Select Funds

# %% [markdown]
# ## 3. Weight Prep

# %% [markdown]
# ## 4. Analysis (In-Sample & Out-of-Sample)
# Use `trend_analysis.pipeline.run_analysis` for the analysis. Previous helper functions were removed in favor of the module version.

# %% [markdown]
# ## 5. Excel Export
# Creates an Excel file with In-Sample, Out-of-Sample and Equal-weight and User-weight.

# %%
# Deprecated local export_to_excel; use trend_analysis.export.export_to_excel\n

# %% [markdown]
# ## 6. Run Parameters, Widgets & User Inputs
# Here we define some IPython widgets for in-sample/out-of-sample dates, target volatility, monthly cost, etc. Also lets us use custom weights.

# %% [markdown]
# ### Using This Notebook
# 1. Run all cells.
# 2. Call `demo_run()` in a new cell to see a quick example with dummy data.
# 3. To use your own data, load it into a DataFrame (make sure it has a Date column and decimal returns in other columns), then call `pipeline.run_analysis()` and `export_to_excel()`.
# 4. For interactive selection, do:
#    ```python
#    display(ui_inputs)
#    ```
#    Then wire the `apply_button` to a callback function that reads the widget values and runs `pipeline.run_analysis()`.
# 5. For custom weights, call:
#    ```python
#    my_weights = get_custom_weights(selected_funds)
#    ```
#    Then pass `my_weights` into your logic.

# %%
from trend_analysis.core.rank_selection import build_ui
from IPython.display import display

display(build_ui())
# Out:
# VBox(children=(VBox(children=(ToggleButtons(description='Source:', options=('Path/URL', 'Browse'), value='Path…
